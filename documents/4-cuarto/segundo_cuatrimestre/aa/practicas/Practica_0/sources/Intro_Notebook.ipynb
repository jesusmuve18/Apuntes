# %% [markdown]
# <b><h1>Ejemplo de creación de celdas de texto</h1></b>

# %% [markdown]
# Esto es una celda de texto.
# <h1>Aquí hay un texto en grande</h1>
# <center> Y aquí un texto centrado</center>
# <b>Ahora en negrita</b> y <u>subrayado</u>
#
# Pongo varios saltos de línea:
# <br><br>
# <br><br>
#
#
# <h2>Texto algo más grande, <b><u>en negrita y subrayado</u></b></h2>
#
# <br><br><br>
# Finalmente, pulsa <b>Mayúsculas-ENTER</b> para <i>"compilar</i> la celda y que se muestre el resultado. <b>Se creará una nueva celda de código a continuación, en caso de no existir ninguna celda.</b>

# %% [markdown]
# <b><h1>Ejemplo de creación de celdas de código</h1></b>

# %% [markdown]
# La siguiente celda es de código. Contiene la función <b>print</b> para mostrar mensajes por consola.

# %%
print('Hola, mundo')
print('La función print sirve para mostrar por consola un texto')
print('Pulsa Mayúsculas-ENTER para ejecutar esta celda.')
# Out:
# Hola, mundo
# La función print sirve para mostrar por consola un texto
# Pulsa Mayúsculas-ENTER para ejecutar esta celda.

# %% [markdown]
# También puedes ejecutar una celda haciendo clic con el ratón en el icono. Prueba a mover el ratón a la celda 1 de código (<b>marcada como [1]</b>, es la celda anterior). Verás que aparece un icono para ejecutar. Púlsalo.

# %%
print('Si quieres ejecutar todas las celdas de principio a fin, sólo debes ir al menú "Entorno de ejecución" y pulsar en "Ejecutar todas"')
print('Alternativamente: CTRL-F9')
# Out:
# Si quieres ejecutar todas las celdas de principio a fin, sólo debes ir al menú "Entorno de ejecución" y pulsar en "Ejecutar todas"
# Alternativamente: CTRL-F9

# %% [markdown]
# La siguiente celda es de código y muestra cómo escribir comentarios en Python. Técnicamente, Python sólo permite comentarios con <b>#</b> hasta el final de la línea. Si queremos comentarios de más de una línea, tenemos que hacer uso de cadenas de caracteres multilínea.
#
# <b>PROBLEMA:</b> Si un comentario multilinea se coloca al final de una celda, su contenido se muestra como resultado de ejecución de la misma.

# %%
# Este es un comentario de una única línea

"""
Este es un comentario de varias líneas.
Esta es la segunda línea del comentario.
La tercera.
La cuarta...
"""
# Out:
# '\nEste es un comentario de varias líneas.\nEsta es la segunda línea del comentario.\nLa tercera.\nLa cuarta...\n'

# %% [markdown]
# Ahora tenemos otro ejemplo de comentario multiplínea seguido de la función print

# %%
"""
Voy a hacer uso de la función print
Sólo voy a mostrar un mensaje
"""
print('Ahora no se ve el comentario multilinea')
# Out:
# Ahora no se ve el comentario multilinea

# %% [markdown]
# <b><h1>Ejemplo de uso de bibliotecas externas</h1></b>

# %% [markdown]
# Las bibliotecas, en Python, se estructuran en paquetes.
#
# Podemos incluir una biblioteca Python externa de varias formas:
#
# <ul>
# <li>Haciendo uso de <b>import</b> y el nombre de la biblioteca</li>
# <li>Haciendo uso de <b>import</b>, el nombre de la biblioteca y un <b>alias</b></li>
# </ul>

# %%
import matplotlib # Inclusión de la biblioteca matplotlib
import matplotlib as mpl # Inclusión de la biblioteca matplotlib con alias

# %% [markdown]
# También se pueden incluir <b>paquetes</b> de una biblioteca si no queremos toda su funcionalidad.
#
# Un paquete se carga <b>desde</b> una biblioteca con <b>>from</b> o, directamente, accediendo al nombre del paquete de la biblioteca separando su nombre por puntos.

# %%
from matplotlib import pyplot
import matplotlib.pyplot

# %% [markdown]
# La carga de paquetes también admite alias

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# <b><h1>Ejemplo rápido de generación de gráficas y su visualización en el cuaderno</h1></b>

# %% [markdown]
# Veamos ahora un ejemplo de generación de gráficas con el paquete PyPlot de MatplotLib.

# %%
# Muestra una línea que pasa por los puntos (1,3) y (2,4)
f= plt.plot([1, 2], [3, 4]) # Obtiene la figura deseada
display(f) # La muestra

# %% [markdown]
# <b><h1>Ejemplo de ejecución de la misma celda en la misma sesión</h1></b>

# %% [markdown]
# <b>CUIDADO</b>: Una sesión permanece abierta hasta que no se finalice. Esto quiere decir que todas las variables y objetos se mantienen en memoria y <b>se pueden actualizar</b>
#
# Como ejemplo, pongamos dos líneas de código para asignar una variable x=1 (celda 8) e incrementar su valor (celda 9).
#
# Prueba a ejecutar una única vez la celda 8 y múltiples veces la celda 9

# %%
x= 1 # asignar x=1

# %%
x= x+1
print('x vale: ', x)
# Out:
# x vale:  2

# %% [markdown]
# <b><h1>Comprobación de instalación software necesario para las prácticas</h1></b>

# %% [markdown]
# Vamos a probar ahora que las bibliotecas NumPy y Scikit-Learn están instaladas correctamente, así como la biblioteca TensorFlow. Al importarlas, si están instaladas, no habrá error.

# %%
import sklearn

# %%
import numpy as np

# %%
import tensorflow as tf

# %% [markdown]
# <b><h1>Ejemplo sobre cómo enlazar el cuaderno para acceder a ficheros en nuestro GDrive</h1></b>

# %% [markdown]
# Vamos ahora a enlazar nuestro cuaderno con nuestra cuenta de GDrive. Es necesario <b>montarlo</b> haciendo uso del paquete <b>drive</b> de Google Colab

# %%
from google.colab import drive

drive.mount('/content/drive') # Montar nuestra unidad
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Ahora vamos a cargar la imagen <b>UGR-Logo.png</b> con la biblioteca MatplotLib, y la mostraremos en el cuaderno.

# %%
ruta_base= '/content/drive/MyDrive/AA-Practicas/Practica_0/sources/'
ruta_imagen= 'UGR-Logo.png'

imagen= plt.imread(ruta_base + ruta_imagen)

# %% [markdown]
# Una vez cargada, la mostramos

# %%
f= plt.imshow(imagen)
display(f)
